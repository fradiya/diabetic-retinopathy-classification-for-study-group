# %% [markdown]
# Fetching dataset from Roboflow with API Key

# %%
# !pip install roboflow

from roboflow import Roboflow
import os
os.environ["ROBOFLOW_API_KEY"] = "Q1flzyg1J8Z2OMweLXf3"
rf = Roboflow(api_key=os.getenv("ROBOFLOW_API_KEY"))
project = rf.workspace("weapon-mpr3p").project("ddr-dataset-yyvzp")
version = project.version(1)
dataset = version.download("folder")
# Out:
# Requirement already satisfied: roboflow in ./venv/lib/python3.14/site-packages (1.3.7)
# Requirement already satisfied: certifi in ./venv/lib/python3.14/site-packages (from roboflow) (2026.4.22)
# Requirement already satisfied: idna==3.7 in ./venv/lib/python3.14/site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in ./venv/lib/python3.14/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv/lib/python3.14/site-packages (from roboflow) (1.5.0)
# Requirement already satisfied: matplotlib in ./venv/lib/python3.14/site-packages (from roboflow) (3.10.9)
# Requirement already satisfied: numpy>=1.18.5 in ./venv/lib/python3.14/site-packages (from roboflow) (2.4.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in ./venv/lib/python3.14/site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in ./venv/lib/python3.14/site-packages (from roboflow) (12.2.0)
# Requirement already satisfied: pi-heif<2 in ./venv/lib/python3.14/site-packages (from roboflow) (1.3.0)
# Requirement already satisfied: pillow-avif-plugin<2 in ./venv/lib/python3.14/site-packages (from roboflow) (1.5.5)
# Requirement already satisfied: python-dateutil in ./venv/lib/python3.14/site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in ./venv/lib/python3.14/site-packages (from roboflow) (1.2.2)
# Requirement already satisfied: requests in ./venv/lib/python3.14/site-packages (from roboflow) (2.33.1)
# Requirement already satisfied: six in ./venv/lib/python3.14/site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in ./venv/lib/python3.14/site-packages (from roboflow) (2.6.3)
# Requirement already satisfied: tqdm>=4.41.0 in ./venv/lib/python3.14/site-packages (from roboflow) (4.67.3)
# Requirement already satisfied: PyYAML>=5.3.1 in ./venv/lib/python3.14/site-packages (from roboflow) (6.0.3)
# Requirement already satisfied: requests_toolbelt in ./venv/lib/python3.14/site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in ./venv/lib/python3.14/site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: typer>=0.12.0 in ./venv/lib/python3.14/site-packages (from roboflow) (0.25.1)
# Requirement already satisfied: click>=8.2.1 in ./venv/lib/python3.14/site-packages (from typer>=0.12.0->roboflow) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in ./venv/lib/python3.14/site-packages (from typer>=0.12.0->roboflow) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in ./venv/lib/python3.14/site-packages (from typer>=0.12.0->roboflow) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in ./venv/lib/python3.14/site-packages (from typer>=0.12.0->roboflow) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./venv/lib/python3.14/site-packages (from rich>=13.8.0->typer>=0.12.0->roboflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./venv/lib/python3.14/site-packages (from rich>=13.8.0->typer>=0.12.0->roboflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in ./venv/lib/python3.14/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer>=0.12.0->roboflow) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.14/site-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.14/site-packages (from matplotlib->roboflow) (4.62.1)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.14/site-packages (from matplotlib->roboflow) (26.2)
# Requirement already satisfied: pyparsing>=3 in ./venv/lib/python3.14/site-packages (from matplotlib->roboflow) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.14/site-packages (from requests->roboflow) (3.4.7)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: pip install --upgrade pip
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# Training Model with YOLO

# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in ./venv/lib/python3.14/site-packages (8.4.46)
# Requirement already satisfied: numpy>=1.23.0 in ./venv/lib/python3.14/site-packages (from ultralytics) (2.4.4)
# Requirement already satisfied: matplotlib>=3.3.0 in ./venv/lib/python3.14/site-packages (from ultralytics) (3.10.9)
# Requirement already satisfied: opencv-python>=4.6.0 in ./venv/lib/python3.14/site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in ./venv/lib/python3.14/site-packages (from ultralytics) (12.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in ./venv/lib/python3.14/site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in ./venv/lib/python3.14/site-packages (from ultralytics) (2.33.1)
# Requirement already satisfied: scipy>=1.4.1 in ./venv/lib/python3.14/site-packages (from ultralytics) (1.17.1)
# Requirement already satisfied: torch>=1.8.0 in ./venv/lib/python3.14/site-packages (from ultralytics) (2.11.0)
# Requirement already satisfied: torchvision>=0.9.0 in ./venv/lib/python3.14/site-packages (from ultralytics) (0.26.0)
# Requirement already satisfied: psutil>=5.8.0 in ./venv/lib/python3.14/site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in ./venv/lib/python3.14/site-packages (from ultralytics) (1.40.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in ./venv/lib/python3.14/site-packages (from ultralytics) (2.0.19)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (26.2)
# Requirement already satisfied: pyparsing>=3 in ./venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.40.1 in ./venv/lib/python3.14/site-packages (from polars>=0.20.0->ultralytics) (1.40.1)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.14/site-packages (from requests>=2.23.0->ultralytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.14/site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in ./venv/lib/python3.14/site-packages (from requests>=2.23.0->ultralytics) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in ./venv/lib/python3.14/site-packages (from requests>=2.23.0->ultralytics) (2026.4.22)
# Requirement already satisfied: filelock in ./venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools<82 in ./venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in ./venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in ./venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in ./venv/lib/python3.14/site-packages (from torch>=1.8.0->ultralytics) (2026.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.14/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.14/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: pip install --upgrade pip

# %%
from ultralytics import YOLO

model = YOLO('yolo11s-cls.pt')

model.train(
    data=dataset.location,
    epochs=15,
    imgsz=224,
    batch=32,
    name="improved-model",
    amp=False,
    device="cpu",
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11s-cls.pt to 'yolo11s-cls.pt': 100% ━━━━━━━━━━━━ 13.0MB 1.7MB/s 7.7s 7.7s<0.0ss.1s
# Ultralytics 8.4.46 🚀 Python-3.14.4 torch-2.11.0 CPU (Apple M1)
# engine/trainer: agnostic_nms=False, amp=False, angle=1.0, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/Users/indah/diabetic-retinopathy-classification-for-study-group/DDR-dataset-1, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=15, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11s-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=improved-model, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/Users/indah/diabetic-retinopathy-classification-for-study-group/runs/classify/improved-model, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /Users/indah/diabetic-retinopathy-classification-for-study-group/DDR-dataset-1/train... found 9498 images in 6 classes ✅
# val: /Users/indah/diabetic-retinopathy-classification-for-study-group/DDR-dataset-1/valid... found 2721 images in 6 classes ✅
# test: /Users/indah/diabetic-retinopathy-classification-for-study-group/DDR-dataset-1/test... found 1354 images in 6 classes ✅
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  10                  -1  1    665606  ultralytics.nn.modules.head.Classify         [512, 6]
# YOLO11s-cls summary: 86 layers, 5,450,694 parameters, 5,450,694 gradients, 12.1 GFLOPs
# Transferred 234/236 items from pretrained weights
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 20.8±5.9 MB/s, size: 4.7 KB)
# train: Scanning /Users/indah/diabetic-retinopathy-classification-for-study-group/DDR-dataset-1/train... 9498 images, 0 corrupt: 100% ━━━━━━━━━━━━ 9498/9498 10.0Git/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 18.9±5.3 MB/s, size: 4.4 KB)
# val: Scanning /Users/indah/diabetic-retinopathy-classification-for-study-group/DDR-dataset-1/valid... 2721 images, 0 corrupt: 100% ━━━━━━━━━━━━ 2721/2721 877.9Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.0005), 40 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 0 dataloader workers
# Logging results to /Users/indah/diabetic-retinopathy-classification-for-study-group/runs/classify/improved-model
# Starting training for 15 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/15         0G      1.042         26        224: 100% ━━━━━━━━━━━━ 297/297 1.7s/it 8:31<1.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 43/43 1.7s/it 1:121.7sss
#                    all      0.668      0.999
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/15         0G     0.8789         26        224: 100% ━━━━━━━━━━━━ 297/297 1.8s/it 8:56<1.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 43/43 1.8s/it 1:191.8sss
#                    all       0.71      0.999
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/15         0G     0.8527         26        224: 100% ━━━━━━━━━━━━ 297/297 2.0s/it 9:52<1.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 43/43 1.8s/it 1:181.8sss
#                    all      0.725      0.999
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/15         0G     0.8118         26        224: 100% ━━━━━━━━━━━━ 297/297 1.8s/it 8:59<1.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 43/43 1.9s/it 1:201.9sss
#                    all      0.724      0.999
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/15         0G     0.7532         26        224: 100% ━━━━━━━━━━━━ 297/297 2.0s/it 9:45<1.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 43/43 2.8s/it 2:002.9sss
#                    all      0.729          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/15         0G     0.7318         26        224: 100% ━━━━━━━━━━━━ 297/297 2.0s/it 9:43<2.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 43/43 1.8s/it 1:181.8sss
#                    all      0.763      0.999
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/15         0G     0.6937         26        224: 100% ━━━━━━━━━━━━ 297/297 2.0s/it 9:56<2.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 43/43 2.6s/it 1:532.7sss
#                    all      0.732      0.999
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/15         0G     0.6916         26        224: 100% ━━━━━━━━━━━━ 297/297 2.0s/it 9:50<1.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 43/43 2.0s/it 1:252.0sss
#                    all       0.76      0.999
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/15         0G     0.6638         26        224: 100% ━━━━━━━━━━━━ 297/297 2.0s/it 10:08<1.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 43/43 1.7s/it 1:151.8sss
#                    all      0.771      0.999
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/15         0G     0.6471         26        224: 100% ━━━━━━━━━━━━ 297/297 1.8s/it 8:44<1.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 43/43 1.7s/it 1:141.7sss
#                    all      0.756      0.999
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/15         0G     0.6301         26        224: 100% ━━━━━━━━━━━━ 297/297 1.9s/it 9:34<2.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 43/43 1.8s/it 1:191.8sss
#                    all      0.773      0.999
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/15         0G     0.6039         26        224: 100% ━━━━━━━━━━━━ 297/297 2.0s/it 9:48<2.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 43/43 1.8s/it 1:181.9sss
#                    all      0.782      0.999
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/15         0G     0.5826         26        224: 100% ━━━━━━━━━━━━ 297/297 1.9s/it 9:38<2.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 43/43 2.1s/it 1:301.9sss
#                    all      0.784      0.999
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/15         0G     0.5597         26        224: 100% ━━━━━━━━━━━━ 297/297 1.8s/it 9:04<1.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 43/43 1.6s/it 1:111.7s4s
#                    all      0.786      0.999
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/15         0G     0.5404         26        224: 100% ━━━━━━━━━━━━ 297/297 1.7s/it 8:23<1.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 43/43 1.7s/it 1:111.7sss
#                    all      0.798      0.999
#
# 15 epochs completed in 2.694 hours.
# Optimizer stripped from /Users/indah/diabetic-retinopathy-classification-for-study-group/runs/classify/improved-model/weights/last.pt, 11.0MB
# Optimizer stripped from /Users/indah/diabetic-retinopathy-classification-for-study-group/runs/classify/improved-model/weights/best.pt, 11.0MB
#
# Validating /Users/indah/diabetic-retinopathy-classification-for-study-group/runs/classify/improved-model/weights/best.pt...
# Ultralytics 8.4.46 🚀 Python-3.14.4 torch-2.11.0 CPU (Apple M1)
# YOLO11s-cls summary (fused): 47 layers, 5,441,814 parameters, 0 gradients, 12.0 GFLOPs
# train: /Users/indah/diabetic-retinopathy-classification-for-study-group/DDR-dataset-1/train... found 9498 images in 6 classes ✅
# val: /Users/indah/diabetic-retinopathy-classification-for-study-group/DDR-dataset-1/valid... found 2721 images in 6 classes ✅
# test: /Users/indah/diabetic-retinopathy-classification-for-study-group/DDR-dataset-1/test... found 1354 images in 6 classes ✅
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 43/43 1.6s/it 1:091.6sss
#                    all      0.797      0.999
# Speed: 0.0ms preprocess, 24.4ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /Users/indah/diabetic-retinopathy-classification-for-study-group/runs/classify/improved-model
# ultralytics.utils.metrics.ClassifyMetrics object with attributes:
#
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x125637d10>
# curves: []
# curves_results: []
# fitness: 0.8980154395103455
# keys: ['metrics/accuracy_top1', 'metrics/accuracy_top5']
# results_dict: {'metrics/accuracy_top1': 0.796765923500061, 'metrics/accuracy_top5': 0.9992649555206299, 'fitness': 0.8980154395103455}
# save_dir: PosixPath('/Users/indah/diabetic-retinopathy-classification-for-study-group/runs/classify/improved-model')
# speed: {'preprocess': 0.00031703969316999604, 'inference': 24.380052340315146, 'loss': 9.433665439980746e-06, 'postprocess': 2.8896364052679003e-05}
# top1: 0.796765923500061
# top5: 0.9992649555206299
